# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # Timeseries

# %%
filename = 'training_log_20171129_500batch_100epochs_timeseries_feedforward_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.figure()
plt.plot(csv_data['epoch'], csv_data['acc'], label='training')
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='validation')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Timeries input + Dense model')
plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
# (0.5, 1)

# %%
filename = 'training_log_20171129_500batch_100epochs_timeseries_convolutional_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.figure()
plt.plot(csv_data['epoch'], csv_data['acc'], label='training')
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='validation')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Timeries input + Convolutional model')
plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
# (0.5, 1)

# %% [markdown]
# # Fourier Transform

# %%
filename = 'training_log_20171129_500batch_100epochs_fft_feedforward_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.figure()
plt.plot(csv_data['epoch'], csv_data['acc'], label='training')
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='validation')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Fourier input + Dense model')
plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
# (0.5, 1)

# %%
filename = 'training_log_20171129_500batch_100epochs_fft_convolutional_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.figure()
plt.plot(csv_data['epoch'], csv_data['acc'], label='training')
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='validation')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Fourier input + Convolutional model')
plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
# (0.5, 1)

# %% [markdown]
# # Combination

# %%
filename = 'training_log_20171129_500batch_100epochs_split_feedforward_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.figure()
plt.plot(csv_data['epoch'], csv_data['acc'], label='training')
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='validation')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Combo input + Dense model')
plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
# (0.5, 1)

# %%
filename = 'training_log_20171129_500batch_100epochs_split_convolutional_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.figure()
plt.plot(csv_data['epoch'], csv_data['acc'], label='training')
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='validation')
plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Combo input + Convolutional model')
plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
# (0.5, 1)

# %% [markdown]
# ## Compare Convolutional Networks

# %%
plt.figure()

filename = 'training_log_20171129_500batch_100epochs_split_convolutional_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='split')

filename = 'training_log_20171129_500batch_100epochs_timeseries_convolutional_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='timeseries')

filename = 'training_log_20171129_500batch_100epochs_fft_convolutional_model.csv'
csv_data = np.genfromtxt(filename, dtype=None, delimiter=',', names=True)
plt.plot(csv_data['epoch'], csv_data['val_acc'], label='fft')

plt.legend(loc='best')
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.title('Convolutional models')
#plt.ylim(0.5, 1)
# Out:
# <img src="data:image/png;base64,..." width="639.4736922348636">
